# %% [markdown]
# Please note that this notebook is for demonstation puposes only and uses a dummy dataset

# %%
#importing useful libraries
import pandas as pd
from sklearn.preprocessing import  MinMaxScaler 
from sklearn.neural_network import MLPClassifier,MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import svm
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LogisticRegression, Ridge
from sklearn.metrics import roc_auc_score


import sys
sys.path.append("/")  # path contains data_prep.py
import data_prep as EHR

# %% [markdown]
# loading dataset and plausible data dictionary

# %%
data = EHR.import_data("DUMMY_DATA.csv")

plausible_values = EHR.import_data("PLAUSIBLE_EHR.csv")

# %% [markdown]
# Applying some functions from data_prep.py

# %%
# Impute missing values with median
data=data[data.columns].fillna(data[data.columns].median())

# %%
# Unify capitalization for ethnicity column
data= EHR.capitalization_fix(data,["Ethnicity"])

# %%
plausible_values=plausible_values.dropna(how='all')
plausible_values=plausible_values.drop("Unit of Measure", axis=1)
plausible_values.set_index('Variable Name',inplace=True)
plausible_values= plausible_values.transpose()
plausible_values.head()
# Out:
# Variable Name            Albumin  Arterial_partial_pressure_co2  Arterial_ph  \
# Minmum Plausible value       0.5                            5.0          6.3
# Maximum Plausible value      6.5                          250.0          8.5
#
# Variable Name            Bilirubin    BUN  Calcium  Creatinine  glucose  Hco3  \
# Minmum Plausible value         1.0    0.5      0.0         0.1      0.0   1.0
# Maximum Plausible value     1200.0  100.0      5.3        33.9   1620.0  80.0
#
# Variable Name            heartrate  ...  Resprate_Rate  Sodium  \
# Minmum Plausible value         1.0  ...            1.0     1.0
# Maximum Plausible value      300.0  ...           80.0   215.0
#
# Variable Name            Oxygen_saturation  Temperature    WBC  Urineoutput  \
# Minmum Plausible value                21.0         20.0    0.0          0.0
# Maximum Plausible value              100.0         46.0  300.0      30000.0
#
# Variable Name            Systolic_blood_pressure_max  \
# Minmum Plausible value                           1.0
# Maximum Plausible value                        250.0
#
# Variable Name            Systolic_blood_pressure_min  \
# Minmum Plausible value                           1.0
# Maximum Plausible value                        250.0
#
# Variable Name            Diastolic_blood_pressure_min  \
# Minmum Plausible value                            1.0
# Maximum Plausible value                         350.0
#
# Variable Name            Diastolic_blood_pressure_max
# Minmum Plausible value                            1.0
# Maximum Plausible value                         350.0
#
# [2 rows x 28 columns]

# %%
# Trying one hot_encoding for a column "Gender"
data= EHR.One_hot_encode(data, "Gender")
data.head()
# Out:
#    encounter_id  Hospital Death  Height  Weight         Ethnicity   Age  \
# 0         34937               1  160.44   57.79          hispanic  56.0
# 1        483670               0  160.44   57.79             asian  53.0
# 2        150725               1  175.14   57.79  african american  56.0
# 3        278547               0  183.08   57.79  african american  56.0
# 4        457468               0  162.62   73.88  african american  58.0
#
#    Diagnosis code  Albumin  Arterial_partial_pressure_co2  Arterial_ph  ...  \
# 0           355.5      3.0                           34.0          7.0  ...
# 1           355.5      3.0                           29.0          7.0  ...
# 2           249.0      1.0                          127.0          7.0  ...
# 3           355.5      6.0                           68.0          8.0  ...
# 4           355.5      6.0                          225.0          7.0  ...
#
#    Oxygen_saturation  Temperature    WBC  Urineoutput  \
# 0               68.0         22.0  300.0        259.0
# 1               17.0         87.0  228.0         47.0
# 2               41.0         45.0  172.0        281.0
# 3               14.0         60.0  172.0         86.0
# 4               14.0         79.0  172.0         15.0
#
#    Systolic_blood_pressure_max  Systolic_blood_pressure_min  \
# 0                         66.0                         52.8
# 1                        118.0                         94.4
# 2                        171.0                        136.8
# 3                        177.0                        141.6
# 4                        158.0                        126.4
#
#    Diastolic_blood_pressure_min  Diastolic_blood_pressure_max  F  M
# 0                           2.4                           3.6  0  1
# 1                           3.2                           4.8  0  0
# 2                           2.4                           3.6  0  0
# 3                           4.0                           6.0  0  0
# 4                           0.8                           1.2  0  0
#
# [5 rows x 37 columns]

# %%
# Trying Label encoding for a column "Ethnicity"
data= EHR.Label_encode(data, "Ethnicity")
data.head()
# Out:
#    encounter_id  Hospital Death  Height  Weight  Ethnicity   Age  \
# 0         34937               1  160.44   57.79          3  56.0
# 1        483670               0  160.44   57.79          1  53.0
# 2        150725               1  175.14   57.79          0  56.0
# 3        278547               0  183.08   57.79          0  56.0
# 4        457468               0  162.62   73.88          0  58.0
#
#    Diagnosis code  Albumin  Arterial_partial_pressure_co2  Arterial_ph  ...  \
# 0           355.5      3.0                           34.0          7.0  ...
# 1           355.5      3.0                           29.0          7.0  ...
# 2           249.0      1.0                          127.0          7.0  ...
# 3           355.5      6.0                           68.0          8.0  ...
# 4           355.5      6.0                          225.0          7.0  ...
#
#    Oxygen_saturation  Temperature    WBC  Urineoutput  \
# 0               68.0         22.0  300.0        259.0
# 1               17.0         87.0  228.0         47.0
# 2               41.0         45.0  172.0        281.0
# 3               14.0         60.0  172.0         86.0
# 4               14.0         79.0  172.0         15.0
#
#    Systolic_blood_pressure_max  Systolic_blood_pressure_min  \
# 0                         66.0                         52.8
# 1                        118.0                         94.4
# 2                        171.0                        136.8
# 3                        177.0                        141.6
# 4                        158.0                        126.4
#
#    Diastolic_blood_pressure_min  Diastolic_blood_pressure_max  F  M
# 0                           2.4                           3.6  0  1
# 1                           3.2                           4.8  0  0
# 2                           2.4                           3.6  0  0
# 3                           4.0                           6.0  0  0
# 4                           0.8                           1.2  0  0
#
# [5 rows x 37 columns]

# %%
# grouping patients per age group 
data= EHR.group_age(data)
data= EHR.Label_encode(data, "age_by_range")

data.head()
# Out:
#    encounter_id  Hospital Death  Height  Weight  Ethnicity   Age  \
# 0         34937               1  160.44   57.79          3  56.0
# 1        483670               0  160.44   57.79          1  53.0
# 2        150725               1  175.14   57.79          0  56.0
# 3        278547               0  183.08   57.79          0  56.0
# 4        457468               0  162.62   73.88          0  58.0
#
#    Diagnosis code  Albumin  Arterial_partial_pressure_co2  Arterial_ph  ...  \
# 0           355.5      3.0                           34.0          7.0  ...
# 1           355.5      3.0                           29.0          7.0  ...
# 2           249.0      1.0                          127.0          7.0  ...
# 3           355.5      6.0                           68.0          8.0  ...
# 4           355.5      6.0                          225.0          7.0  ...
#
#    Temperature    WBC  Urineoutput  Systolic_blood_pressure_max  \
# 0         22.0  300.0        259.0                         66.0
# 1         87.0  228.0         47.0                        118.0
# 2         45.0  172.0        281.0                        171.0
# 3         60.0  172.0         86.0                        177.0
# 4         79.0  172.0         15.0                        158.0
#
#    Systolic_blood_pressure_min  Diastolic_blood_pressure_min  \
# 0                         52.8                           2.4
# 1                         94.4                           3.2
# 2                        136.8                           2.4
# 3                        141.6                           4.0
# 4                        126.4                           0.8
#
#    Diastolic_blood_pressure_max  F  M  age_by_range
# 0                           3.6  0  1             1
# 1                           4.8  0  0             1
# 2                           3.6  0  0             1
# 3                           6.0  0  0             1
# 4                           1.2  0  0             1
#
# [5 rows x 38 columns]

# %% [markdown]
# Get feature transformations from non-null values in imbalanced training set

# %%
columns = list(data.columns)
transforms = {}
for c in columns:
    scaler_mean = MinMaxScaler(feature_range=(0,1))
    _=scaler_mean.fit_transform(data[[c]].dropna())
    transforms[c] = scaler_mean

# %%
def transformations(dataset, columns, transforms):
    dataset_copy = dataset.copy()
    for c in columns:
        func = [value for key, value in transforms.items() if key in c][0]
        func = transforms[c]
        dataset_copy[c] = func.transform(dataset_copy[c].values.reshape(len(dataset_copy), 1))   
    return dataset_copy

# %% [markdown]
# Splitting the data into training and testing sets

# %%
# Splitting the data into training and testing sets
X_train, X_test = train_test_split(data, test_size=0.2, random_state =0)

# %%
training_data_transformed = transformations(X_train, columns, transforms)
test_data_transformed = transformations(X_test, columns, transforms)
y_train=X_train["Hospital Death"]
y_test=X_test["Hospital Death"]
X_train= X_train.drop("Hospital Death", axis =1)
X_test= X_test.drop("Hospital Death", axis =1)
training_data_transformed= training_data_transformed.drop("Hospital Death", axis =1)
test_data_transformed= test_data_transformed.drop("Hospital Death", axis =1)

# %% [markdown]
# # Please note that the dataset at hand contains dummy values which are not reflective of real EHRs. This explains the low auc scores shown below

# %% [markdown]
# Logistic Regression

# %%
# LogisticRegression
clf = LogisticRegression(random_state=256).fit(training_data_transformed, y_train)
prediction =clf.predict_proba(test_data_transformed)[:,1]
score = roc_auc_score(y_test,prediction)
print("roc_auc_score: ")
score
# Out:
# roc_auc_score:
# 0.5383989421218595

# %% [markdown]
# Multi-layer Perceptron regressor

# %%
# Multi-layer Perceptron regressor
clf =MLPRegressor(hidden_layer_sizes=(400,200,128), max_iter=1000, learning_rate='constant',
                 activation='relu', solver='adam',random_state=0).fit(training_data_transformed, y_train)
prediction =clf.predict(X_test)
score = roc_auc_score(y_test,prediction)
print("roc_auc_score: ")
score
# Out:
# roc_auc_score:
# 0.49465974977113214

# %% [markdown]
# Support Vector Machine

# %%
#  Support Vector Machine
clf = svm.SVC(cache_size=7000,random_state=0).fit(training_data_transformed, y_train)
prediction =clf.predict(X_test)
score = roc_auc_score(y_test,prediction)
print("roc_auc_score: ")
score
# Out:
# roc_auc_score:
# 0.5

# %% [markdown]
# Gradient Boosting Regressor

# %%
# Gradient Boosting Regressor
clf= GradientBoostingRegressor(random_state=0).fit(training_data_transformed, y_train)
prediction =clf.predict(X_test)
score = roc_auc_score(y_test,prediction)
print("roc_auc_score: ")
score
# Out:
# roc_auc_score:
# 0.4299155731868578

# %% [markdown]
#  Ridge Regressor

# %%
# Ridge Regressor
clf = Ridge(alpha=200, copy_X=True, fit_intercept=True, max_iter=None,
      normalize=False, random_state=0, solver='auto', tol=0.001).fit(training_data_transformed, y_train)
prediction =clf.predict(test_data_transformed)
score = roc_auc_score(y_test,prediction)
print("roc_auc_score: ")
score
# Out:
# roc_auc_score:
# 0.5198860746617842
